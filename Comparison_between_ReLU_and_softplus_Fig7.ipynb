# %%
## Without Duplicate Training Data
## Input features: Pressure, H2 to N2 ratio
import numpy as np
import pandas as pd
import itertools
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE, SMOTENC, RandomOverSampler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.optimizers import Adam

data2 = np.array([[0, 0.5, 0.36],
[20.49, 0.5, 0.69],
[39.18, 0.5, 0.96],
[59.59, 0.5, 1.21],
[79.93, 0.5, 1.43],
[0, 1, 0.58],
[10.24, 1, 0.79],
[20.11, 1, 0.96],
[39.33, 1, 1.23],
[59.44, 1, 1.44],
[75.44, 1, 1.55],
[79.85, 1, 1.57],
[0, 2, 0.60],
[10.09, 2, 0.78],
[20.41, 2, 0.94],
[39.18, 2, 1.15],
[59.51, 2, 1.29],
[75.59, 2, 1.34],
[80, 2, 1.34],
[0, 3, 0.61],
[10.32, 3, 0.71],
[20.56, 3, 0.79],
[39.18, 3, 0.91],
[59.44, 3, 1],
[79.85, 3, 1.03],
[0, 5, 0.51],
[10.32, 5, 0.56],
[20.49, 5, 0.59],
[39.33, 5, 0.65],
[59.66, 5, 0.67],
[79.85, 5, 0.68],
                    [80, 1, 1.57],
                    [80, 1, 1.16],
                    [80, 1, 1.02],
                    [80, 1, 1.89]])

# Convert data2 into a DataFrame
my_column_names = ['Pressure(psig)','H2 to N2 ratio','Ammonia Concentration(%)']
data2 = pd.DataFrame(data=data2, columns=my_column_names)

data2VariableNames = data2.columns.tolist()
feaColums = data2VariableNames[1:3]
labels = data2VariableNames[3:]

data2Del = data2.drop_duplicates(subset=feaColums,keep='first',inplace=False)
#print(data2Del)

ind_list = [i for i in range(data2Del.shape[0])]
#print(ind_list)

ind_set = list(itertools.combinations(ind_list,2))
#print(ind_set)

model_smote = SMOTE(k_neighbors=1,random_state=0)

data_smote_all = []
ind_smote_all = []
ind_smote = np.zeros(data2Del.shape[0]-5)
#print(ind_smote)

ind_smote[:2] = 1
#print(ind_smote[:2])
smote_data = []
i = 0

for item in ind_set:
    ind_ = list(item)
    y_smote = np.zeros(data2Del.shape[0])
    y_smote[ind_] = 1
    i +=1
    data_smote_resampled, y_smote_resampled = model_smote.fit_resample(data2Del, y_smote)
    smote_data.append(data_smote_resampled)

# Convert the list to a NumPy array
smote_data = np.array(smote_data)
smote_data = smote_data.reshape(-1, 3)
#print(smote_data.shape)


# Convert the array to a list of tuples to preserve the 2D structure
smote_data_tuples = [tuple(row) for row in smote_data]

# Storing unique data points
unique_tuples = np.unique(smote_data_tuples, axis=0)

# Convert the unique tuples back to a NumPy array
smote_data_array = np.array(unique_tuples)
#print(smote_data_array .shape)
smote_data_feature = smote_data_array[:, :2]
smote_data_label = smote_data_array[:, 2]

# Add random perturbations to the target variable
synthetic_y = smote_data_array[:, 2]

## Establishing Neural Network
# define the deep neural network model
model = Sequential()
model.add(Dense(64, input_dim=2, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))


# compile the model
opt = Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=opt)

# train the model on the training set
model.fit(smote_data_feature, synthetic_y, epochs=100, batch_size=3)
history_train = model.fit(smote_data_feature, synthetic_y, epochs=100, batch_size=3)

# Constant values
# Temperature = 320
# Gas_flow_rate = 100

# pressure range with an increment of 1
Pressure_range = range(0, 81, 1)

###############################################################################
Ratio_Exp = 0.5

# Creating array for input features
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=0.5')
plt.scatter([0,20,40,80],[0.4,0.63,0.99,1.41])
plt.xlabel('Pressure(psig)')
plt.ylabel('NH3 concentration(%)')
plt.legend()

###############################################################################
Ratio_Exp = 1
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=1')
plt.scatter([0,20,40,60,75,80],[0.57,0.95,1.24,1.43,1.55,1.57])
plt.legend()
###############################################################################
Ratio_Exp = 2
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=2')
plt.scatter([0,20,40,60,75,80],[0.6,0.96,1.16,1.27,1.33,1.35])
plt.legend()
###############################################################################
Ratio_Exp = 3
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=3')
plt.scatter([0,20,40,80],[0.56,0.85,0.89,1.06])
plt.legend()
###############################################################################
Ratio_Exp = 5
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=5')
plt.scatter([0,20,40,80],[0.48,0.63,0.63,0.69])
plt.legend()
# Out:
# Epoch 1/100
# 5115/5115 [==============================] - 24s 4ms/step - loss: 0.0680
# Epoch 2/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0310
# Epoch 3/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0265
# Epoch 4/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0248
# Epoch 5/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0223
# Epoch 6/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0208
# Epoch 7/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0203
# Epoch 8/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0194
# Epoch 9/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0190
# Epoch 10/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0189
# Epoch 11/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0183
# Epoch 12/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0175
# Epoch 13/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0169
# Epoch 14/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0169
# Epoch 15/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0164
# Epoch 16/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0164
# Epoch 17/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0163
# Epoch 18/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0160
# Epoch 19/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0158
# Epoch 20/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0158
# Epoch 21/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0156
# Epoch 22/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0154
# Epoch 23/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0155
# Epoch 24/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0154
# Epoch 25/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0153
# Epoch 26/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0152
# Epoch 27/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0153
# Epoch 28/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0152
# Epoch 29/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 30/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0152
# Epoch 31/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0152
# Epoch 32/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 33/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 34/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0151
# Epoch 35/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0151
# Epoch 36/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 37/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 38/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 39/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 40/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 41/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 42/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 43/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 44/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 45/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 46/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 47/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 48/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 49/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 50/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 51/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 52/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 53/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 54/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 55/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 56/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 57/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 58/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 59/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 60/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0148
# Epoch 61/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 62/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 63/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 64/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 65/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 66/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 67/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 68/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 69/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 70/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 71/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 72/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 73/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 74/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 75/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0148
# Epoch 76/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 77/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 78/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 79/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 80/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 81/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 82/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 83/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 84/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 85/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 86/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 87/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 88/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0147
# Epoch 89/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 90/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 91/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 92/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 93/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 94/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 95/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 96/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 97/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 98/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0146
# Epoch 99/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 100/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 1/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 2/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0146
# Epoch 3/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 4/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 5/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 6/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 7/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 8/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 9/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 10/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 11/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 12/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 13/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 14/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 15/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 16/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 17/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0146
# Epoch 18/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 19/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 20/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 21/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 22/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 23/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 24/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 25/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 26/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 27/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 28/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 29/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 30/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 31/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 32/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 33/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0145
# Epoch 34/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 35/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 36/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 37/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 38/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 39/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 40/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 41/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 42/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 43/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 44/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 45/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 46/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 47/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 48/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0146
# Epoch 49/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 50/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 51/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 52/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 53/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 54/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 55/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 56/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 57/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 58/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 59/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 60/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 61/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 62/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 63/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0145
# Epoch 64/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 65/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 66/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 67/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 68/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 69/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 70/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 71/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 72/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 73/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 74/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 75/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 76/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 77/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 78/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0145
# Epoch 79/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 80/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 81/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 82/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 83/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 84/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 85/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 86/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 87/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 88/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 89/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 90/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 91/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0144
# Epoch 92/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 93/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0145
# Epoch 94/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 95/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 96/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 97/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 98/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# Epoch 99/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0145
# Epoch 100/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0145
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 3ms/step

# %%
## Without Duplicate Training Data
## Input features: Pressure, H2 to N2 ratio
import numpy as np
import pandas as pd
import itertools
from imblearn.over_sampling import SMOTE, BorderlineSMOTE, SVMSMOTE, SMOTENC, RandomOverSampler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.optimizers import Adam

data2 = np.array([[0, 0.5, 0.36],
[20.49, 0.5, 0.69],
[39.18, 0.5, 0.96],
[59.59, 0.5, 1.21],
[79.93, 0.5, 1.43],
[0, 1, 0.58],
[10.24, 1, 0.79],
[20.11, 1, 0.96],
[39.33, 1, 1.23],
[59.44, 1, 1.44],
[75.44, 1, 1.55],
[79.85, 1, 1.57],
[0, 2, 0.60],
[10.09, 2, 0.78],
[20.41, 2, 0.94],
[39.18, 2, 1.15],
[59.51, 2, 1.29],
[75.59, 2, 1.34],
[80, 2, 1.34],
[0, 3, 0.61],
[10.32, 3, 0.71],
[20.56, 3, 0.79],
[39.18, 3, 0.91],
[59.44, 3, 1],
[79.85, 3, 1.03],
[0, 5, 0.51],
[10.32, 5, 0.56],
[20.49, 5, 0.59],
[39.33, 5, 0.65],
[59.66, 5, 0.67],
[79.85, 5, 0.68],
                    [80, 1, 1.57],
                    [80, 1, 1.16],
                    [80, 1, 1.02],
                    [80, 1, 1.89]])

# Convert data2 into a DataFrame
my_column_names = ['Pressure(psig)','H2 to N2 ratio','Ammonia Concentration(%)']
data2 = pd.DataFrame(data=data2, columns=my_column_names)

data2VariableNames = data2.columns.tolist()
feaColums = data2VariableNames[1:3]
labels = data2VariableNames[3:]

data2Del = data2.drop_duplicates(subset=feaColums,keep='first',inplace=False)
#print(data2Del)

ind_list = [i for i in range(data2Del.shape[0])]
#print(ind_list)

ind_set = list(itertools.combinations(ind_list,2))
#print(ind_set)

model_smote = SMOTE(k_neighbors=1,random_state=0)

data_smote_all = []
ind_smote_all = []
ind_smote = np.zeros(data2Del.shape[0]-5)
#print(ind_smote)

ind_smote[:2] = 1
#print(ind_smote[:2])
smote_data = []
i = 0

for item in ind_set:
    ind_ = list(item)
    y_smote = np.zeros(data2Del.shape[0])
    y_smote[ind_] = 1
    i +=1
    data_smote_resampled, y_smote_resampled = model_smote.fit_resample(data2Del, y_smote)
    smote_data.append(data_smote_resampled)

# Convert the list to a NumPy array
smote_data = np.array(smote_data)
smote_data = smote_data.reshape(-1, 3)
#print(smote_data.shape)


# Convert the array to a list of tuples to preserve the 2D structure
smote_data_tuples = [tuple(row) for row in smote_data]

# Storing unique data points
unique_tuples = np.unique(smote_data_tuples, axis=0)

# Convert the unique tuples back to a NumPy array
smote_data_array = np.array(unique_tuples)
#print(smote_data_array .shape)
smote_data_feature = smote_data_array[:, :2]
smote_data_label = smote_data_array[:, 2]

# Add random perturbations to the target variable
synthetic_y = smote_data_array[:, 2]

## Establishing Neural Network
# define the deep neural network model
model = Sequential()
model.add(Dense(64, input_dim=2, activation='softplus'))
model.add(Dense(128, activation='softplus'))
model.add(Dense(64, activation='softplus'))
model.add(Dense(1, activation='linear'))


# compile the model
opt = Adam(learning_rate=0.0001)
model.compile(loss='mse', optimizer=opt)

# train the model on the training set
model.fit(smote_data_feature, synthetic_y, epochs=100, batch_size=3)
history_train = model.fit(smote_data_feature, synthetic_y, epochs=100, batch_size=3)

# Constant values
# Temperature = 320
# Gas_flow_rate = 100

# pressure range with an increment of 1
Pressure_range = range(0, 81, 1)

###############################################################################
Ratio_Exp = 0.5

# Creating array for input features
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=0.5')
plt.scatter([0,20,40,80],[0.4,0.63,0.99,1.41])
plt.xlabel('Pressure(psig)')
plt.ylabel('NH3 concentration(%)')
plt.legend()

###############################################################################
Ratio_Exp = 1
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=1')
plt.scatter([0,20,40,60,75,80],[0.57,0.95,1.24,1.43,1.55,1.57])
plt.legend()
###############################################################################
Ratio_Exp = 2
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=2')
plt.scatter([0,20,40,60,75,80],[0.6,0.96,1.16,1.27,1.33,1.35])
plt.legend()
###############################################################################
Ratio_Exp = 3
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=3')
plt.scatter([0,20,40,80],[0.56,0.85,0.89,1.06])
plt.legend()
###############################################################################
Ratio_Exp = 5
Combined_array = []

for Pressure in Pressure_range:
    Combined_array.append([Pressure, Ratio_Exp])

z_pred = model.predict(Combined_array)

# Extract pressure, ratio, and temperature from Combined_array
pressure = [row[0] for row in Combined_array]
ratio = [row[1] for row in Combined_array]

# Create 2D figure
fig = plt.plot(pressure, z_pred, label='Ratio=5')
plt.scatter([0,20,40,80],[0.48,0.63,0.63,0.69])
plt.legend()
# Out:
# Epoch 1/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0597
# Epoch 2/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0255
# Epoch 3/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0224
# Epoch 4/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0210
# Epoch 5/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0197
# Epoch 6/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0188
# Epoch 7/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0182
# Epoch 8/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0175
# Epoch 9/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0170
# Epoch 10/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0163
# Epoch 11/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0160
# Epoch 12/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0157
# Epoch 13/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0156
# Epoch 14/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0155
# Epoch 15/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0153
# Epoch 16/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0153
# Epoch 17/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0153
# Epoch 18/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0152
# Epoch 19/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0152
# Epoch 20/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0152
# Epoch 21/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0152
# Epoch 22/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 23/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 24/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0151
# Epoch 25/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0151
# Epoch 26/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 27/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 28/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 29/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0151
# Epoch 30/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0150
# Epoch 31/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0150
# Epoch 32/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0150
# Epoch 33/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 34/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 35/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0150
# Epoch 36/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0150
# Epoch 37/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 38/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 39/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 40/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0149
# Epoch 41/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 42/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 43/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0150
# Epoch 44/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 45/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 46/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 47/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 48/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0148
# Epoch 49/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 50/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0149
# Epoch 51/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 52/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 53/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 54/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 55/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 56/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 57/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 58/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 59/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0149
# Epoch 60/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 61/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 62/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 63/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0148
# Epoch 64/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 65/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 66/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 67/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 68/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 69/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 70/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 71/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 72/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 73/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 74/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 75/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 76/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 77/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 78/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 79/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 80/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0147
# Epoch 81/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 82/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 83/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 84/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 85/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0148
# Epoch 86/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0148
# Epoch 87/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 88/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 89/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 90/100
# 5115/5115 [==============================] - 9s 2ms/step - loss: 0.0147
# Epoch 91/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 92/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 93/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 94/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 95/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 96/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 97/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 98/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 99/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0148
# Epoch 100/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 1/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 2/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 3/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 4/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 5/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 6/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 7/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 8/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 9/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 10/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 11/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 12/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 13/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 14/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 15/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 16/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 17/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 18/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 19/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 20/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 21/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 22/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0147
# Epoch 23/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 24/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 25/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 26/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 27/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 28/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 29/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 30/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 31/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 32/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 33/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 34/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 35/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 36/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0147
# Epoch 37/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 38/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 39/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 40/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 41/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 42/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 43/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 44/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 45/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 46/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 47/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 48/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 49/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 50/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 51/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0147
# Epoch 52/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 53/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 54/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 55/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 56/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 57/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 58/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 59/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 60/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 61/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 62/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 63/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 64/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 65/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0146
# Epoch 66/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 67/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 68/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 69/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 70/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 71/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 72/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 73/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 74/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 75/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 76/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 77/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 78/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 79/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 80/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0147
# Epoch 81/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0147
# Epoch 82/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 83/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 84/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 85/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 86/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 87/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 88/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 89/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 90/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0147
# Epoch 91/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 92/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 93/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 94/100
# 5115/5115 [==============================] - 12s 2ms/step - loss: 0.0147
# Epoch 95/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 96/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 97/100
# 5115/5115 [==============================] - 10s 2ms/step - loss: 0.0146
# Epoch 98/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 99/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# Epoch 100/100
# 5115/5115 [==============================] - 11s 2ms/step - loss: 0.0146
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 8ms/step
